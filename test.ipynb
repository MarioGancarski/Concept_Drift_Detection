# %%
from DDM import DDM
from D3 import D3
from datasets import import_dataset
import matplotlib.pyplot as plt

# %%
X, y = import_dataset('datasets/elec.csv')
window_size = 100
rho = 0.1
threshold = 0.75
d3 = D3(X, y, window_size, rho, threshold)
ddm = DDM(X, y)

# %%
error_rate_list, accuracy = d3.run_all_steps()
print(accuracy)
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# 190
# 0.5638571428571428

# %%
error_rate_list, accuracy = ddm.run_all_steps()
print(accuracy)
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# 170
# 81.48834745762711
